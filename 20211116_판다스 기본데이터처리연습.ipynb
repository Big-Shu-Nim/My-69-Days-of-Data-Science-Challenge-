# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('EX_GrapeData.csv')
df
# Out:
#     continent  brand  size  period price
# 0           2      2  10.7   47.65   144
# 1           2      3  14.0   63.13   215
# 2           2      2   9.0   58.76   105
# 3           1      1   8.0   34.88    69
# 4           2      2  10.0   55.53   134
# ..        ...    ...   ...     ...   ...
# 58          1      1   5.0   16.66  21.5
# 59          2      1  21.0   43.00
# 60          2      2   5.0   12.00
# 61          2      3  13.0   20.00
# 62          2      3  31.0   19.00
#
# [63 rows x 5 columns]

# %%
#엑셀불러오기
df2=pd.read_excel("EX_GrapeData.xlsx")
df2
# Out:
#     continent  brand  size  period  price
# 0           2      2  10.7   47.65  144.0
# 1           2      3  14.0   63.13  215.0
# 2           2      2   9.0   58.76  105.0
# 3           1      1   8.0   34.88   69.0
# 4           2      2  10.0   55.53  134.0
# ..        ...    ...   ...     ...    ...
# 58          1      1   5.0   16.66   21.5
# 59          2      1  21.0   43.00    NaN
# 60          2      2   5.0   12.00    NaN
# 61          2      3  13.0   20.00    NaN
# 62          2      3  31.0   19.00    NaN
#
# [63 rows x 5 columns]

# %%
df3= pd.read_csv('cosmetics_csv', encoding='euc-kr')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-1d107f661bc3> in <module>
# ----> 1 df3= pd.read_csv('cosmetics_csv', encoding='euc-kr')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
# ...

# %%
df3= pd.read_csv('cosmetics_.csv', encoding='euc-kr')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-c79d2790c1a5> in <module>
# ----> 1 df3= pd.read_csv('cosmetics_.csv', encoding='euc-kr')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
# ...

# %%
df3= pd.read_excel('cosmetics_.xlsx', encoding='euc-kr')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-e7e2ed2f16dd> in <module>
# ----> 1 df3= pd.read_excel('cosmetics_.xlsx', encoding='euc-kr')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# TypeError: read_excel() got an unexpected keyword argument 'encoding'

# %%
df.head()
# Out:
#    continent  brand  size  period price
# 0          2      2  10.7   47.65   144
# 1          2      3  14.0   63.13   215
# 2          2      2   9.0   58.76   105
# 3          1      1   8.0   34.88    69
# 4          2      2  10.0   55.53   134

# %%
df.tail()
# Out:
#     continent  brand  size  period price
# 58          1      1   5.0   16.66  21.5
# 59          2      1  21.0   43.00
# 60          2      2   5.0   12.00
# 61          2      3  13.0   20.00
# 62          2      3  31.0   19.00

# %%
df[1:5]     #데이터프레임에서 연속적으로 행 확인하기 주의사항:원하는 행의+1 해줘야함
# Out:
#    continent  brand  size  period price
# 1          2      3  14.0   63.13   215
# 2          2      2   9.0   58.76   105
# 3          1      1   8.0   34.88    69
# 4          2      2  10.0   55.53   134

# %%
df[:3] #처음부터 3행까지 [start,end. stpes] 인듯
# Out:
#    continent  brand  size  period price
# 0          2      2  10.7   47.65   144
# 1          2      3  14.0   63.13   215
# 2          2      2   9.0   58.76   105

# %%
#60번째 행부터 마지막까지 출력해보세요.

df[60:]
# Out:
#     continent  brand  size  period price
# 60          2      2   5.0    12.0
# 61          2      3  13.0    20.0
# 62          2      3  31.0    19.0

# %%
#열을 데이터 프레임으로 불러오는 세가지 방법을 실행해보기 [size행만]
df[[size]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-d4a22bf0e8da> in <module>
#       1 #열을 데이터 프레임으로 불러오는 세가지 방법을 실행해보기 [size행만]
# ----> 2 df[[size]]
#
# NameError: name 'size' is not defined

# %%
#열을 데이터 프레임으로 불러오는 세가지 방법을 실행해보기 [size행만]
df[['size']]
# Out:
#     size
# 0   10.7
# 1   14.0
# 2    9.0
# 3    8.0
# 4   10.0
# ..   ...
# 58   5.0
# 59  21.0
# 60   5.0
# 61  13.0
# 62  31.0
#
# [63 rows x 1 columns]

# %%
#열을 데이터 프레임으로 불러오는 세가지 방법을 실행해보기 [bran,size행만]
df.loc[:, 'brand':'size']
# Out:
#     brand  size
# 0       2  10.7
# 1       3  14.0
# 2       2   9.0
# 3       1   8.0
# 4       2  10.0
# ..    ...   ...
# 58      1   5.0
# 59      1  21.0
# 60      2   5.0
# 61      3  13.0
# 62      3  31.0
#
# [63 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   continent  63 non-null     int64
#  1   brand      63 non-null     int64
#  2   size       63 non-null     float64
#  3   period     63 non-null     float64
#  4   price      63 non-null     object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 2.6+ KB

# %%
#열 가져오기 할때 index만 활용해서 불러오기

df[df.columns[[0,2,4]]]
# Out:
#     continent  size price
# 0           2  10.7   144
# 1           2  14.0   215
# 2           2   9.0   105
# 3           1   8.0    69
# 4           2  10.0   134
# ..        ...   ...   ...
# 58          1   5.0  21.5
# 59          2  21.0
# 60          2   5.0
# 61          2  13.0
# 62          2  31.0
#
# [63 rows x 3 columns]

# %%
#열 가져오기 할때 index만 활용해서 불러오기

df[df.columns[[0,2,4]]]   #이거 중괄호 무지 헷갈림
# Out:
#     continent  size price
# 0           2  10.7   144
# 1           2  14.0   215
# 2           2   9.0   105
# 3           1   8.0    69
# 4           2  10.0   134
# ..        ...   ...   ...
# 58          1   5.0  21.5
# 59          2  21.0
# 60          2   5.0
# 61          2  13.0
# 62          2  31.0
#
# [63 rows x 3 columns]

# %%
df.iloc[1:7, 0:2]
# Out:
#    continent  brand
# 1          2      3
# 2          2      2
# 3          1      1
# 4          2      2
# 5          2      2
# 6          2      2

# %%
# 변수명.iloc[첫행:끝행, 첫열:끝열] 행과 열별로 원하는만큼 지정해서 불러오기
#예를들어서 10개행 만, continent, brand, size 칼럼 별로 알고싶다. 
df.iloc[0:9, 0:3]
# Out:
#    continent  brand  size
# 0          2      2  10.7
# 1          2      3  14.0
# 2          2      2   9.0
# 3          1      1   8.0
# 4          2      2  10.0
# 5          2      2  10.5
# 6          2      2  16.0
# 7          2      1  15.0
# 8          2      1   6.5

# %%
# 변수명.iloc[첫행:끝행, 첫열:끝열] 행과 열별로 원하는만큼 지정해서 불러오기
#예를들어서 10개행 만, continent, brand, size 칼럼 별로 알고싶다. 
df.iloc[0:10, 0:3]
# Out:
#    continent  brand  size
# 0          2      2  10.7
# 1          2      3  14.0
# 2          2      2   9.0
# 3          1      1   8.0
# 4          2      2  10.0
# 5          2      2  10.5
# 6          2      2  16.0
# 7          2      1  15.0
# 8          2      1   6.5
# 9          2      1   5.0

# %%
df.at[5, 'price']
# Out:
# '129'

# %%
# 데이터 프렘을 복사하여 백업하시오
df_columns=df.copy()

# %%
df_columns
# Out:
#     continent  brand  size  period price
# 0           2      2  10.7   47.65   144
# 1           2      3  14.0   63.13   215
# 2           2      2   9.0   58.76   105
# 3           1      1   8.0   34.88    69
# 4           2      2  10.0   55.53   134
# ..        ...    ...   ...     ...   ...
# 58          1      1   5.0   16.66  21.5
# 59          2      1  21.0   43.00
# 60          2      2   5.0   12.00
# 61          2      3  13.0   20.00
# 62          2      3  31.0   19.00
#
# [63 rows x 5 columns]

# %%
df_columns.columns
# Out:
# Index(['continent', 'brand', 'size', 'period', 'price'], dtype='object')

# %%
df_columns=df_columns[['size','period','price']]
df_columns.head()
#특정변수 필터링
# Out:
#    size  period price
# 0  10.7   47.65   144
# 1  14.0   63.13   215
# 2   9.0   58.76   105
# 3   8.0   34.88    69
# 4  10.0   55.53   134

# %%
#변수이름 바꾸기 period라는 칼럼의 이름을 time으로 바꾸시오.
df_columns.rename(columns={'period':'time'}, inplace=True)  #inplace는 덮어씌우기 하겠냐?라는 의미이다. 
df_columns.colmuns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-ae02aa6c220a> in <module>
#       1 #변수이름 바꾸기 period라는 칼럼의 이름을 time으로 바꾸시오.
#       2 df_columns.rename(columns={'period':'time'}, inplace=True)  #inplace는 덮어씌우기 하겠냐?라는 의미이다.
# ----> 3 df_columns.colmuns
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'colmuns'

# %%
#변수이름 바꾸기 period라는 칼럼의 이름을 time으로 바꾸시오.
df_columns.rename(columns={'period':'time'}, inplace=True)  #inplace는 덮어씌우기 하겠냐?라는 의미이다. 
df_columns.columns
# Out:
# Index(['size', 'time', 'price'], dtype='object')

# %%
df_columns.rename(columns={'size':'사이즈'})
df_columns.columns
# Out:
# Index(['size', 'time', 'price'], dtype='object')

# %%
df_columns.rename(columns={'size':'사이즈'}, inplace=True)
df_columns.columns
# Out:
# Index(['사이즈', 'time', 'price'], dtype='object')

# %%
#기존 칼럼 계산 이후 새로운 칼럼 만들기; size를 time으로 나누어 월별 포도크기로 계산하여 growth 변수를 생성하시오. 
df_columns['groth']=df_columns['size']/df_columns['time']
df_columns.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'size'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-1689aa99cba9> in <module>
# ...

# %%
#기존 칼럼 계산 이후 새로운 칼럼 만들기; size를 time으로 나누어 월별 포도크기로 계산하여 growth 변수를 생성하시오. 
df_columns['groth']=df_columns['사이즈']/df_columns['time']
df_columns.head()
# Out:
#     사이즈   time price     groth
# 0  10.7  47.65   144  0.224554
# 1  14.0  63.13   215  0.221765
# 2   9.0  58.76   105  0.153165
# 3   8.0  34.88    69  0.229358
# 4  10.0  55.53   134  0.180083

# %%
#특정변수 지우기 
del df_columns['groth']
df_columnns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-41b96eb76d30> in <module>
#       1 #특정변수 지우기
#       2 del df_columns['groth']
# ----> 3 df_columnns
#
# NameError: name 'df_columnns' is not defined

# %%
#특정변수 지우기 
del df_columns['groth']
df_columns
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'groth'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-139a0caf33c2> in <module>
#       1 #특정변수 지우기
# ...

# %%
#특정변수 지우기 
del df_columns['growth']
df_columns
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'growth'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-cdf6d0e14db3> in <module>
#       1 #특정변수 지우기
# ...

# %%
#특정변수 지우기 
del df_columns['growth']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'growth'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-e7fe9997eb6c> in <module>
#       1 #특정변수 지우기
# ...

# %%
df_columnns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-2116da796057> in <module>
# ----> 1 df_columnns
#
# NameError: name 'df_columnns' is not defined

# %%
df_columns
# Out:
#      사이즈   time price
# 0   10.7  47.65   144
# 1   14.0  63.13   215
# 2    9.0  58.76   105
# 3    8.0  34.88    69
# 4   10.0  55.53   134
# ..   ...    ...   ...
# 58   5.0  16.66  21.5
# 59  21.0  43.00
# 60   5.0  12.00
# 61  13.0  20.00
# 62  31.0  19.00
#
# [63 rows x 3 columns]

# %%
#케이스 추출 대륙이 1이고 브랜드가 1인 별도의 데이터셋을 뽑아서 데이터셋을 구성하시오.
df_contitnent_brand=df[(df['continent']==1) & (df['brand']==1)]
df_continent_brand.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-79d44d3c76e2> in <module>
#       1 #케이스 추출 대륙이 1이고 브랜드가 1인 별도의 데이터셋을 뽑아서 데이터셋을 구성하시오.
#       2 df_contitnent_brand=df[(df['continent']==1) & (df['brand']==1)]
# ----> 3 df_continent_brand.head()
#
# NameError: name 'df_continent_brand' is not defined

# %%
#케이스 추출 대륙이 1이고 브랜드가 1인 별도의 데이터셋을 뽑아서 데이터셋을 구성하시오.
df_continent_brand=df[(df['continent']==1) & (df['brand']==1)]
df_continent_brand.head()
# Out:
#     continent  brand  size  period price
# 3           1      1   8.0   34.88    69
# 11          1      1  10.4   17.67    54
# 12          1      1   7.4   16.41    39
# 13          1      1   5.4   12.02  29.5
# 16          1      1   6.0   23.21    42

# %%
new=df[(df['price']>50)&(df['period']>20)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-12ed7ab7a095> in <module>
# ----> 1 new=df[(df['price']>50)&(df['period']>20)]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py in __gt__(self, other)
#      43     @unpack_zerodim_and_defer("__gt__")
#      44     def __gt__(self, other):
# ---> 45         return self._cmp_method(other, operator.gt)
#      46
#      47     @unpack_zerodim_and_defer("__ge__")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    4976         rvalues = extract_array(other, extract_numpy=True)
#    4977
# ...

# %%
new=df[(df['price']>=50)&(df['period']>=20)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-f5c388d9416c> in <module>
# ----> 1 new=df[(df['price']>=50)&(df['period']>=20)]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py in __ge__(self, other)
#      47     @unpack_zerodim_and_defer("__ge__")
#      48     def __ge__(self, other):
# ---> 49         return self._cmp_method(other, operator.ge)
#      50
#      51     # -------------------------------------------------------------
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _cmp_method(self, other, op)
# ...

# %%
df_over_size_period=df[(df['size']>=10)& (df['period']>=30)]
df_over_size_period.head()
# Out:
#    continent  brand  size  period price
# 0          2      2  10.7   47.65   144
# 1          2      3  14.0   63.13   215
# 4          2      2  10.0   55.53   134
# 5          2      2  10.5   43.14   129
# 6          2      2  16.0   54.86   155

# %%
df['brand'].value_counts()
# Out:
# 2    24
# 1    23
# 3    16
# Name: brand, dtype: int64

# %%
recode_brand={'brand': {1:1, 2:1, 3:2}}
df_recode1 = df.replace(recode_brand)
df_recode1.head()
# Out:
#    continent  brand  size  period price
# 0          2      1  10.7   47.65   144
# 1          2      2  14.0   63.13   215
# 2          2      1   9.0   58.76   105
# 3          1      1   8.0   34.88    69
# 4          2      1  10.0   55.53   134

# %%
df_recode1.value_counts()
# Out:
# continent  brand  size  period  price
# 1          1      5.0   16.66   21.5     1
# 2          1      12.4  48.74   89.5     1
#                   5.5   26.53   22       1
#                   6.5   17.46   38.5     1
#                   7.5   20.83   23       1
#                                         ..
# 1          2      12.0  45.78   119      1
#                   13.0  39.71   93       1
#                   14.0  32.62   109      1
#                   14.2  37.11   109      1
# 2          2      31.0  19.00            1
# Length: 63, dtype: int64

# %%
df_recode1['brand'].value_counts()
# Out:
# 1    47
# 2    16
# Name: brand, dtype: int64

# %%
def brand_groups(series):
    if series==1:
        return 1
    elif series==2:
        return 1
    elif series==3:
        return 2

df['re_brand']=df['brand'].apply(brand_groups)
df.head()
# Out:
#    continent  brand  size  period price  re_brand
# 0          2      2  10.7   47.65   144         1
# 1          2      3  14.0   63.13   215         2
# 2          2      2   9.0   58.76   105         1
# 3          1      1   8.0   34.88    69         1
# 4          2      2  10.0   55.53   134         1

# %%
import pandas as pd
df= pd.read_csv('EX_GrapeData.csv')
df.head()
# Out:
#    continent  brand  size  period price
# 0          2      2  10.7   47.65   144
# 1          2      3  14.0   63.13   215
# 2          2      2   9.0   58.76   105
# 3          1      1   8.0   34.88    69
# 4          2      2  10.0   55.53   134

# %%
df_num=df.to_numpy()
df_num
# Out:
# array([[2, 2, 10.7, 47.65, '144'],
#        [2, 3, 14.0, 63.13, '215'],
#        [2, 2, 9.0, 58.76, '105'],
#        [1, 1, 8.0, 34.88, '69'],
#        [2, 2, 10.0, 55.53, '134'],
#        [2, 2, 10.5, 43.14, '129'],
#        [2, 2, 16.0, 54.86, '155'],
#        [2, 1, 15.0, 44.14, '99'],
#        [2, 1, 6.5, 17.46, '38.5'],
#        [2, 1, 5.0, 21.04, '36.5'],
#        [2, 2, 25.0, 109.38, '260'],
#        [1, 1, 10.4, 17.67, '54'],
#        [1, 1, 7.4, 16.41, '39'],
#        [1, 1, 5.4, 12.02, '29.5'],
#        [2, 2, 15.4, 49.48, '109'],
#        [2, 1, 12.4, 48.74, '89.5'],
#        [1, 1, 6.0, 23.21, '42'],
#        [1, 1, 9.0, 28.64, '65'],
#        [1, 3, 9.0, 44.95, '115'],
#        [1, 1, 12.4, 23.77, '49.5'],
#        [1, 1, 7.5, 20.21, '36.5'],
#        [1, 3, 14.0, 32.62, '109'],
#        [1, 1, 7.0, 17.84, '45'],
#        [1, 2, 9.0, 22.82, '58'],
#        [1, 2, 12.0, 29.48, '89'],
#        [1, 1, 5.5, 15.61, '30'],
#        [1, 2, 6.0, 13.25, '31'],
# ...

# %%
df_pd= pd.DataFrame(df_num)
df_pd.head()
# Out:
#    0  1     2      3    4
# 0  2  2  10.7  47.65  144
# 1  2  3  14.0  63.13  215
# 2  2  2   9.0  58.76  105
# 3  1  1   8.0  34.88   69
# 4  2  2  10.0  55.53  134

# %%
df_pd2= pd.DataFrame(data = df_num, columns =['continent','brand','size','period','price'])
df_pd2.head()
# Out:
#   continent brand  size period price
# 0         2     2  10.7  47.65   144
# 1         2     3  14.0  63.13   215
# 2         2     2   9.0  58.76   105
# 3         1     1   8.0  34.88    69
# 4         2     2  10.0  55.53   134
