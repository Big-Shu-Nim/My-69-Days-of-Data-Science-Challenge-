# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
data= pd.read_csv('Ex_CEOSalary.csv', encoding=utf-8)

data.info()
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3b8c9d091227> in <module>
# ----> 1 data= pd.read_csv('Ex_CEOSalary.csv', encoding=utf-8)
#       2
#       3 data.info()
#       4 data.head()
#
# NameError: name 'utf' is not defined

# %%
data= pd.read_csv('Ex_CEOSalary.csv', encoding='utf-8')

data.info()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   salary    209 non-null    int64
#  1   sales     209 non-null    float64
#  2   roe       209 non-null    float64
#  3   industry  209 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 6.7 KB
#    salary         sales   roe  industry
# 0    1095  27595.000000  14.1         1
# 1    1001   9958.000000  10.9         1
# 2    1122   6125.899902  23.5         1
# 3     578  16246.000000   5.9         1
# 4    1368  21783.199219  13.8         1

# %%
data['log_salary']=np.log(data['salary'])
data['log_sales']=np.log(data['sales'])
data['log_roe']=np.log(data['roe'])
data.head()
# Out:
#    salary         sales   roe  industry  log_salary  log_sales   log_roe
# 0    1095  27595.000000  14.1         1    6.998510  10.225390  2.646175
# 1    1001   9958.000000  10.9         1    6.908755   9.206132  2.388763
# 2    1122   6125.899902  23.5         1    7.022868   8.720281  3.157000
# 3     578  16246.000000   5.9         1    6.359574   9.695602  1.774952
# 4    1368  21783.199219  13.8         1    7.221105   9.988894  2.624669

# %%
data.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'salary'}>,
#         <AxesSubplot:title={'center':'sales'}>,
#         <AxesSubplot:title={'center':'roe'}>],
#        [<AxesSubplot:title={'center':'industry'}>,
#         <AxesSubplot:title={'center':'log_salary'}>,
#         <AxesSubplot:title={'center':'log_sales'}>],
#        [<AxesSubplot:title={'center':'log_roe'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
data.corr()
# Out:
#               salary     sales       roe  industry  log_salary  log_sales  \
# salary      1.000000  0.119869  0.114842 -0.015725    0.794208   0.194092
# sales       0.119869  1.000000 -0.055386 -0.100284    0.281286   0.742921
# roe         0.114842 -0.055386  1.000000 -0.011833    0.208499  -0.122553
# industry   -0.015725 -0.100284 -0.011833  1.000000   -0.173583  -0.118576
# log_salary  0.794208  0.281286  0.208499 -0.173583    1.000000   0.459148
# log_sales   0.194092  0.742921 -0.122553 -0.118576    0.459148   1.000000
# log_roe     0.101526 -0.041004  0.873419 -0.051647    0.163548  -0.120642
#
#              log_roe
# salary      0.101526
# sales      -0.041004
# roe         0.873419
# industry   -0.051647
# log_salary  0.163548
# log_sales  -0.120642
# log_roe     1.000000

# %%
#로그 스케일과 루트 스퀘어는 쉽게 이상치를 바꿀수 있지만 단위값이 바뀐다.

# %%
data['sqrt_salary']=np.sqrt(data['salary'])
data['sqrt_sales']=np.sqrt(data['sales'])
data['sqrt_roe']=np.sqrt(data['roe'])

# %%
data.hist(bins=20, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'salary'}>,
#         <AxesSubplot:title={'center':'sales'}>,
#         <AxesSubplot:title={'center':'roe'}>],
#        [<AxesSubplot:title={'center':'industry'}>,
#         <AxesSubplot:title={'center':'log_salary'}>,
#         <AxesSubplot:title={'center':'log_sales'}>],
#        [<AxesSubplot:title={'center':'log_roe'}>,
#         <AxesSubplot:title={'center':'sqrt_salary'}>,
#         <AxesSubplot:title={'center':'sqrt_sales'}>],
#        [<AxesSubplot:title={'center':'sqrt_roe'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
data.corr()
# Out:
#                salary     sales       roe  industry  log_salary  log_sales  \
# salary       1.000000  0.119869  0.114842 -0.015725    0.794208   0.194092
# sales        0.119869  1.000000 -0.055386 -0.100284    0.281286   0.742921
# roe          0.114842 -0.055386  1.000000 -0.011833    0.208499  -0.122553
# industry    -0.015725 -0.100284 -0.011833  1.000000   -0.173583  -0.118576
# log_salary   0.794208  0.281286  0.208499 -0.173583    1.000000   0.459148
# log_sales    0.194092  0.742921 -0.122553 -0.118576    0.459148   1.000000
# log_roe      0.101526 -0.041004  0.873419 -0.051647    0.163548  -0.120642
# sqrt_salary  0.945732  0.215716  0.172327 -0.094616    0.946014   0.342422
# sqrt_sales   0.164340  0.936282 -0.087687 -0.125441    0.386456   0.920797
# sqrt_roe     0.115219 -0.050538  0.977012 -0.036050    0.197914  -0.129020
#
#               log_roe  sqrt_salary  sqrt_sales  sqrt_roe
# salary       0.101526     0.945732    0.164340  0.115219
# sales       -0.041004     0.215716    0.936282 -0.050538
# roe          0.873419     0.172327   -0.087687  0.977012
# industry    -0.051647    -0.094616   -0.125441 -0.036050
# log_salary   0.163548     0.946014    0.386456  0.197914
# log_sales   -0.120642     0.342422    0.920797 -0.129020
# log_roe      1.000000     0.139470   -0.083308  0.953806
# sqrt_salary  0.139470     1.000000    0.293173  0.165932
# sqrt_sales  -0.083308     0.293173    1.000000 -0.089501
# sqrt_roe     0.953806     0.165932   -0.089501  1.000000

# %%
data=p.read_csv('Ex_Missing.csv')
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-9c85036e3925> in <module>
# ----> 1 data=p.read_csv('Ex_Missing.csv')
#       2 data
#
# NameError: name 'p' is not defined

# %%
data=pd.read_csv('Ex_Missing.csv')
data
# Out:
#    salary         sales        roe  industry
# 0  1095.0  27595.000000  14.100000         1
# 1     NaN   9958.000000  10.900000         1
# 2     NaN   6125.899902  23.500000         1
# 3   578.0  16246.000000   5.900000         1
# 4  1368.0           NaN  13.800000         1
# 5  1145.0           NaN  20.000000         2
# 6  1078.0   2266.699951  16.400000         2
# 7  1094.0   2966.800049  16.299999         2
# 8  1237.0   4570.200195  10.500000         2
# 9   833.0   2830.000000        NaN         2

# %%
pd.isunull(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-1bddeff1f872> in <module>
# ----> 1 pd.isunull(data)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'isunull'

# %%
pd.isnull(data)
# Out:
#    salary  sales    roe  industry
# 0   False  False  False     False
# 1    True  False  False     False
# 2    True  False  False     False
# 3   False  False  False     False
# 4   False   True  False     False
# 5   False   True  False     False
# 6   False  False  False     False
# 7   False  False  False     False
# 8   False  False  False     False
# 9   False  False   True     False

# %%
pd.notnull(data)
data.notnull()
# Out:
#    salary  sales    roe  industry
# 0    True   True   True      True
# 1   False   True   True      True
# 2   False   True   True      True
# 3    True   True   True      True
# 4    True  False   True      True
# 5    True  False   True      True
# 6    True   True   True      True
# 7    True   True   True      True
# 8    True   True   True      True
# 9    True   True  False      True

# %%
data.isnull().sum()
# Out:
# salary      2
# sales       2
# roe         1
# industry    0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# salary       8
# sales        8
# roe          9
# industry    10
# dtype: int64

# %%
data['salary'].isnull().sum()
# Out:
# 2

# %%
data.isnull().sum(1)
# Out:
# 0    0
# 1    1
# 2    1
# 3    0
# 4    1
# 5    1
# 6    0
# 7    0
# 8    0
# 9    1
# dtype: int64

# %%
data['missing']=data.isnull().sum(1)
data
# Out:
#    salary         sales        roe  industry  missing
# 0  1095.0  27595.000000  14.100000         1        0
# 1     NaN   9958.000000  10.900000         1        1
# 2     NaN   6125.899902  23.500000         1        1
# 3   578.0  16246.000000   5.900000         1        0
# 4  1368.0           NaN  13.800000         1        1
# 5  1145.0           NaN  20.000000         2        1
# 6  1078.0   2266.699951  16.400000         2        0
# 7  1094.0   2966.800049  16.299999         2        0
# 8  1237.0   4570.200195  10.500000         2        0
# 9   833.0   2830.000000        NaN         2        1

# %%
del data['missing']
data['valid']=data.notnull().sum(1)
data
# Out:
#    salary         sales        roe  industry  valid
# 0  1095.0  27595.000000  14.100000         1      4
# 1     NaN   9958.000000  10.900000         1      3
# 2     NaN   6125.899902  23.500000         1      3
# 3   578.0  16246.000000   5.900000         1      4
# 4  1368.0           NaN  13.800000         1      3
# 5  1145.0           NaN  20.000000         2      3
# 6  1078.0   2266.699951  16.400000         2      4
# 7  1094.0   2966.800049  16.299999         2      4
# 8  1237.0   4570.200195  10.500000         2      4
# 9   833.0   2830.000000        NaN         2      3

# %%
data_del_row=data.dropna(axis=0)
dta.del_row
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-abf095273306> in <module>
#       1 data_del_row=data.dropna(axis=0)
# ----> 2 dta.del_row
#
# NameError: name 'dta' is not defined

# %%
data_del_row=data.dropna(axis=0)
data.del_row
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-94218393a3e1> in <module>
#       1 data_del_row=data.dropna(axis=0)
# ----> 2 data.del_row
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'del_row'

# %%
data_del_row=data.dropna(axis=0)
data_del_row
# Out:
#    salary         sales        roe  industry  valid
# 0  1095.0  27595.000000  14.100000         1      4
# 3   578.0  16246.000000   5.900000         1      4
# 6  1078.0   2266.699951  16.400000         2      4
# 7  1094.0   2966.800049  16.299999         2      4
# 8  1237.0   4570.200195  10.500000         2      4

# %%
data.del_col=data.dropna(axis=1)
data_del_col
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-c7f91f45dbf2> in <module>
#       1 data.del_col=data.dropna(axis=1)
# ----> 2 data_del_col
#
# NameError: name 'data_del_col' is not defined

# %%
data_del_col=data.dropna(axis=1)
data_del_col
# Out:
#    industry  valid
# 0         1      4
# 1         1      3
# 2         1      3
# 3         1      4
# 4         1      3
# 5         2      3
# 6         2      4
# 7         2      4
# 8         2      4
# 9         2      3

# %%
data[['salary']].dropna()
# Out:
#    salary
# 0  1095.0
# 3   578.0
# 4  1368.0
# 5  1145.0
# 6  1078.0
# 7  1094.0
# 8  1237.0
# 9   833.0

# %%
data
# Out:
#    salary         sales        roe  industry  valid
# 0  1095.0  27595.000000  14.100000         1      4
# 1     NaN   9958.000000  10.900000         1      3
# 2     NaN   6125.899902  23.500000         1      3
# 3   578.0  16246.000000   5.900000         1      4
# 4  1368.0           NaN  13.800000         1      3
# 5  1145.0           NaN  20.000000         2      3
# 6  1078.0   2266.699951  16.400000         2      4
# 7  1094.0   2966.800049  16.299999         2      4
# 8  1237.0   4570.200195  10.500000         2      4
# 9   833.0   2830.000000        NaN         2      3

# %%
data[['salary'.'sales','roe','industry']].dropna()
# Out:
#   File "<ipython-input-29-2c83bc405c46>", line 1
#     data[['salary'.'sales','roe','industry']].dropna()
#                    ^
# SyntaxError: invalid syntax

# %%
data[['salary','sales','roe','industry']].dropna()
# Out:
#    salary         sales        roe  industry
# 0  1095.0  27595.000000  14.100000         1
# 3   578.0  16246.000000   5.900000         1
# 6  1078.0   2266.699951  16.400000         2
# 7  1094.0   2966.800049  16.299999         2
# 8  1237.0   4570.200195  10.500000         2

# %%
data[['salary','sales','roe','industry']].dropna()(axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-d7259882e522> in <module>
# ----> 1 data[['salary','sales','roe','industry']].dropna()(axis=1)
#
# TypeError: 'DataFrame' object is not callable

# %%
data[['salary','sales','roe','industry']].dropna(axis=1)
# Out:
#    industry
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# 5         2
# 6         2
# 7         2
# 8         2
# 9         2

# %%
data_0 = data.faillna(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-ca0f2270b4f2> in <module>
# ----> 1 data_0 = data.faillna(0)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'faillna'

# %%
data_0 = data.fillna(0)

# %%
data_0
# Out:
#    salary         sales        roe  industry  valid
# 0  1095.0  27595.000000  14.100000         1      4
# 1     0.0   9958.000000  10.900000         1      3
# 2     0.0   6125.899902  23.500000         1      3
# 3   578.0  16246.000000   5.900000         1      4
# 4  1368.0      0.000000  13.800000         1      3
# 5  1145.0      0.000000  20.000000         2      3
# 6  1078.0   2266.699951  16.400000         2      4
# 7  1094.0   2966.800049  16.299999         2      4
# 8  1237.0   4570.200195  10.500000         2      4
# 9   833.0   2830.000000   0.000000         2      3

# %%
data_missing = data.fillna('missing')
data_missing
# Out:
#     salary        sales        roe  industry  valid
# 0   1095.0      27595.0       14.1         1      4
# 1  missing       9958.0       10.9         1      3
# 2  missing  6125.899902       23.5         1      3
# 3    578.0      16246.0        5.9         1      4
# 4   1368.0      missing       13.8         1      3
# 5   1145.0      missing       20.0         2      3
# 6   1078.0  2266.699951       16.4         2      4
# 7   1094.0  2966.800049  16.299999         2      4
# 8   1237.0  4570.200195       10.5         2      4
# 9    833.0       2830.0    missing         2      3

# %%
data.fill=data.filna(method='ffill')
data_ffill
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-19b4634231c2> in <module>
# ----> 1 data.fill=data.filna(method='ffill')
#       2 data_ffill
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'filna'

# %%
data.fill=data.filna(method='ffill')
data_fill
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-a9d06e78dd59> in <module>
# ----> 1 data.fill=data.filna(method='ffill')
#       2 data_fill
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'filna'

# %%
data_ffill=data.filna(method='ffill')
data_ffill
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-b8f619798146> in <module>
# ----> 1 data_ffill=data.filna(method='ffill')
#       2 data_ffill
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'filna'

# %%
data_ffill=data.fillna(method='ffill')
data_ffill
# Out:
#    salary         sales        roe  industry  valid
# 0  1095.0  27595.000000  14.100000         1      4
# 1  1095.0   9958.000000  10.900000         1      3
# 2  1095.0   6125.899902  23.500000         1      3
# 3   578.0  16246.000000   5.900000         1      4
# 4  1368.0  16246.000000  13.800000         1      3
# 5  1145.0  16246.000000  20.000000         2      3
# 6  1078.0   2266.699951  16.400000         2      4
# 7  1094.0   2966.800049  16.299999         2      4
# 8  1237.0   4570.200195  10.500000         2      4
# 9   833.0   2830.000000  10.500000         2      3

# %%
data_bfill=data.filna(method='pad')
data_bfill
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-6fcb57c18ee0> in <module>
# ----> 1 data_bfill=data.filna(method='pad')
#       2 data_bfill
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'filna'

# %%
data_bfill=data.fillna(method='pad')
data_bfill
# Out:
#    salary         sales        roe  industry  valid
# 0  1095.0  27595.000000  14.100000         1      4
# 1  1095.0   9958.000000  10.900000         1      3
# 2  1095.0   6125.899902  23.500000         1      3
# 3   578.0  16246.000000   5.900000         1      4
# 4  1368.0  16246.000000  13.800000         1      3
# 5  1145.0  16246.000000  20.000000         2      3
# 6  1078.0   2266.699951  16.400000         2      4
# 7  1094.0   2966.800049  16.299999         2      4
# 8  1237.0   4570.200195  10.500000         2      4
# 9   833.0   2830.000000  10.500000         2      3

# %%
data_bfill=data.fillna(method='bfill')
data_bfill
# Out:
#    salary         sales        roe  industry  valid
# 0  1095.0  27595.000000  14.100000         1      4
# 1   578.0   9958.000000  10.900000         1      3
# 2   578.0   6125.899902  23.500000         1      3
# 3   578.0  16246.000000   5.900000         1      4
# 4  1368.0   2266.699951  13.800000         1      3
# 5  1145.0   2266.699951  20.000000         2      3
# 6  1078.0   2266.699951  16.400000         2      4
# 7  1094.0   2966.800049  16.299999         2      4
# 8  1237.0   4570.200195  10.500000         2      4
# 9   833.0   2830.000000        NaN         2      3

# %%
df.fillna(df.mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-a2478f315f9e> in <module>
# ----> 1 df.fillna(df.mean())
#
# NameError: name 'df' is not defined

# %%
data_mean=data.fillna(mean())
data_mean
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-cdc691291d38> in <module>
# ----> 1 data_mean=data.fillna(mean())
#       2 data_mean
#
# NameError: name 'mean' is not defined

# %%
data_mean=data.fillna(data.mean())
data_mean
# Out:
#    salary         sales        roe  industry  valid
# 0  1095.0  27595.000000  14.100000         1      4
# 1  1053.5   9958.000000  10.900000         1      3
# 2  1053.5   6125.899902  23.500000         1      3
# 3   578.0  16246.000000   5.900000         1      4
# 4  1368.0   9069.825012  13.800000         1      3
# 5  1145.0   9069.825012  20.000000         2      3
# 6  1078.0   2266.699951  16.400000         2      4
# 7  1094.0   2966.800049  16.299999         2      4
# 8  1237.0   4570.200195  10.500000         2      4
# 9   833.0   2830.000000  14.600000         2      3

# %%
data_median= data.fillna(median())
data_median
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-bdca796fec3c> in <module>
# ----> 1 data_median= data.fillna(median())
#       2 data_median
#
# NameError: name 'median' is not defined

# %%
data_median= data.fillna(data.median())
data_median
# Out:
#    salary         sales        roe  industry  valid
# 0  1095.0  27595.000000  14.100000         1      4
# 1  1094.5   9958.000000  10.900000         1      3
# 2  1094.5   6125.899902  23.500000         1      3
# 3   578.0  16246.000000   5.900000         1      4
# 4  1368.0   5348.050049  13.800000         1      3
# 5  1145.0   5348.050049  20.000000         2      3
# 6  1078.0   2266.699951  16.400000         2      4
# 7  1094.0   2966.800049  16.299999         2      4
# 8  1237.0   4570.200195  10.500000         2      4
# 9   833.0   2830.000000  14.100000         2      3

# %%
data_max = data.filna(data.max())
data_max
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-24b6d8ca4d1b> in <module>
# ----> 1 data_max = data.filna(data.max())
#       2 data_max
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'filna'

# %%
data_max = data.fillna(data.max())
data_max
# Out:
#    salary         sales        roe  industry  valid
# 0  1095.0  27595.000000  14.100000         1      4
# 1  1368.0   9958.000000  10.900000         1      3
# 2  1368.0   6125.899902  23.500000         1      3
# 3   578.0  16246.000000   5.900000         1      4
# 4  1368.0  27595.000000  13.800000         1      3
# 5  1145.0  27595.000000  20.000000         2      3
# 6  1078.0   2266.699951  16.400000         2      4
# 7  1094.0   2966.800049  16.299999         2      4
# 8  1237.0   4570.200195  10.500000         2      4
# 9   833.0   2830.000000  23.500000         2      3

# %%
data_min = data.fillna(data.min())
data_min
# Out:
#    salary         sales        roe  industry  valid
# 0  1095.0  27595.000000  14.100000         1      4
# 1   578.0   9958.000000  10.900000         1      3
# 2   578.0   6125.899902  23.500000         1      3
# 3   578.0  16246.000000   5.900000         1      4
# 4  1368.0   2266.699951  13.800000         1      3
# 5  1145.0   2266.699951  20.000000         2      3
# 6  1078.0   2266.699951  16.400000         2      4
# 7  1094.0   2966.800049  16.299999         2      4
# 8  1237.0   4570.200195  10.500000         2      4
# 9   833.0   2830.000000   5.900000         2      3

# %%
import numpy as np
data2 = data.copy()
data2['sales_new'] = np.where(pd.notnull(data2['sales']) == True,
                              data2['sales']. data2['salary'])
data2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-8b8792ebb172> in <module>
#       2 data2 = data.copy()
#       3 data2['sales_new'] = np.where(pd.notnull(data2['sales']) == True,
# ----> 4                               data2['sales']. data2['salary'])
#       5 data2
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'data2'

# %%
data2 = data.copy()
data2['sales_new'] = np.where(pd.notnull(data2['sales']) ==True, data2['sales'], data2['salary'])
data2
# Out:
#    salary         sales        roe  industry  valid     sales_new
# 0  1095.0  27595.000000  14.100000         1      4  27595.000000
# 1     NaN   9958.000000  10.900000         1      3   9958.000000
# 2     NaN   6125.899902  23.500000         1      3   6125.899902
# 3   578.0  16246.000000   5.900000         1      4  16246.000000
# 4  1368.0           NaN  13.800000         1      3   1368.000000
# 5  1145.0           NaN  20.000000         2      3   1145.000000
# 6  1078.0   2266.699951  16.400000         2      4   2266.699951
# 7  1094.0   2966.800049  16.299999         2      4   2966.800049
# 8  1237.0   4570.200195  10.500000         2      4   4570.200195
# 9   833.0   2830.000000        NaN         2      3   2830.000000

# %%
data.groupby('industry').mean()
# Out:
#                salary         sales    roe  valid
# industry
# 1         1013.666667  14981.224975  13.64    3.4
# 2         1077.400000   3158.425049  15.80    3.6

# %%
fill_mean_func = lambda g: g.fillna(g.mean())

# %%
data_group_mean=data.groupby('industry').apply(fill_mean_func)
data_group_mean
# Out:
#                  salary         sales        roe  industry  valid
# industry
# 1        0  1095.000000  27595.000000  14.100000         1      4
#          1  1013.666667   9958.000000  10.900000         1      3
#          2  1013.666667   6125.899902  23.500000         1      3
#          3   578.000000  16246.000000   5.900000         1      4
#          4  1368.000000  14981.224975  13.800000         1      3
# 2        5  1145.000000   3158.425049  20.000000         2      3
#          6  1078.000000   2266.699951  16.400000         2      4
#          7  1094.000000   2966.800049  16.299999         2      4
#          8  1237.000000   4570.200195  10.500000         2      4
#          9   833.000000   2830.000000  15.800000         2      3

# %%
fill_values =[1: 1000, 2: 2000]
# Out:
#   File "<ipython-input-57-2960c00d1585>", line 1
#     fill_values =[1: 1000, 2: 2000]
#                    ^
# SyntaxError: invalid syntax

# %%
fill_values = {1:1000, 2:2000}

# %%
fill_func= lambda d: d.filna(fill_values[d.name])

# %%
data_group_value=data.groupby('industry').apply(fill_func)
data_group_value
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-40e466929bb4> in <module>
# ----> 1 data_group_value=data.groupby('industry').apply(fill_func)
#       2 data_group_value
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     892         with option_context("mode.chained_assignment", None):
#     893             try:
# --> 894                 result = self._python_apply_general(f, self._selected_obj)
#     895             except TypeError:
#     896                 # gh-20949
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data)
#     926             data after applying f
#     927         """
# --> 928         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#     929
#     930         return self._wrap_applied_output(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     236             # group might be modified
#     237             group_axes = group.axes
# --> 238             res = f(group)
#     239             if not _is_indexed_like(res, group_axes, axis):
#     240                 mutated = True
#
# <ipython-input-59-8a4fd3c98f1e> in <lambda>(d)
# ----> 1 fill_func= lambda d: d.filna(fill_values[d.name])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'filna'

# %%
fill_func= lambda d: d.fillna(fill_values[d.name])

# %%
data_group_value=data.groupby('industry').apply(fill_func)
data_group_value
# Out:
#    salary         sales          roe  industry  valid
# 0  1095.0  27595.000000    14.100000         1      4
# 1  1000.0   9958.000000    10.900000         1      3
# 2  1000.0   6125.899902    23.500000         1      3
# 3   578.0  16246.000000     5.900000         1      4
# 4  1368.0   1000.000000    13.800000         1      3
# 5  1145.0   2000.000000    20.000000         2      3
# 6  1078.0   2266.699951    16.400000         2      4
# 7  1094.0   2966.800049    16.299999         2      4
# 8  1237.0   4570.200195    10.500000         2      4
# 9   833.0   2830.000000  2000.000000         2      3

# %%
missing_fill_val = {'salary': data.salary.interpolate(),
                   'sales': data.sales.mean(),
                   'roe':'missing'}
print(missing_fill_val)
# Out:
# {'salary': 0    1095.000000
# 1     922.666667
# 2     750.333333
# 3     578.000000
# 4    1368.000000
# 5    1145.000000
# 6    1078.000000
# 7    1094.000000
# 8    1237.000000
# 9     833.000000
# Name: salary, dtype: float64, 'sales': 9069.825012125, 'roe': 'missing'}

# %%
data_multi= data.fillna(missing_fill_val)
data_multi
# Out:
#         salary         sales        roe  industry  valid
# 0  1095.000000  27595.000000       14.1         1      4
# 1   922.666667   9958.000000       10.9         1      3
# 2   750.333333   6125.899902       23.5         1      3
# 3   578.000000  16246.000000        5.9         1      4
# 4  1368.000000   9069.825012       13.8         1      3
# 5  1145.000000   9069.825012       20.0         2      3
# 6  1078.000000   2266.699951       16.4         2      4
# 7  1094.000000   2966.800049  16.299999         2      4
# 8  1237.000000   4570.200195       10.5         2      4
# 9   833.000000   2830.000000    missing         2      3

# %%
data=pd.read_csv('house_raw.csv')
data.head()
# Out:
#    housing_age  income  bedrooms  households     rooms  house_value
# 0           23  6.7770  0.141112    2.442244  8.103960       500000
# 1           49  6.0199  0.160984    2.726688  5.752412       500000
# 2           35  5.1155  0.249061    1.902676  3.888078       500000
# 3           32  4.7109  0.231383    1.913669  4.508393       500000
# 4           21  4.5625  0.255583    3.092664  4.667954       500000

# %%
data.isnull()
# Out:
#        housing_age  income  bedrooms  households  rooms  house_value
# 0            False   False     False       False  False        False
# 1            False   False     False       False  False        False
# 2            False   False     False       False  False        False
# 3            False   False     False       False  False        False
# 4            False   False     False       False  False        False
# ...            ...     ...       ...         ...    ...          ...
# 17909        False   False     False       False  False        False
# 17910        False   False     False       False  False        False
# 17911        False   False     False       False  False        False
# 17912        False   False     False       False  False        False
# 17913        False   False     False       False  False        False
#
# [17914 rows x 6 columns]

# %%
data.isnull().sum()
# Out:
# housing_age    0
# income         0
# bedrooms       0
# households     0
# rooms          0
# house_value    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17914 entries, 0 to 17913
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   housing_age  17914 non-null  int64
#  1   income       17914 non-null  float64
#  2   bedrooms     17914 non-null  float64
#  3   households   17914 non-null  float64
#  4   rooms        17914 non-null  float64
#  5   house_value  17914 non-null  int64
# dtypes: float64(4), int64(2)
# memory usage: 839.8 KB

# %%
data.describe()
# Out:
#         housing_age        income      bedrooms    households         rooms  \
# count  17914.000000  17914.000000  17914.000000  17914.000000  17914.000000
# mean      27.307022      3.664086      0.214309      3.007667      5.370672
# std       11.297204      1.526694      0.055251      4.579534      2.332776
# min        1.000000      0.499900      0.100000      0.692308      0.846154
# 25%       18.000000      2.526125      0.177544      2.467031      4.426115
# 50%       28.000000      3.447800      0.204256      2.853499      5.199222
# 75%       36.000000      4.583300      0.240476      3.318866      5.970848
# max       51.000000      9.905500      1.000000    599.714286    132.533333
#
#          house_value
# count   17914.000000
# mean   188692.620130
# std     95318.621139
# min     14999.000000
# 25%    114325.000000
# 50%    170800.000000
# 75%    242100.000000
# max    500000.000000

# %%
data.hist(bins=20, figsize(20,15))
# Out:
#   File "<ipython-input-70-fe664ff8411f>", line 1
#     data.hist(bins=20, figsize(20,15))
#                        ^
# SyntaxError: positional argument follows keyword argument

# %%
data.hist(bins=20, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'housing_age'}>,
#         <AxesSubplot:title={'center':'income'}>],
#        [<AxesSubplot:title={'center':'bedrooms'}>,
#         <AxesSubplot:title={'center':'households'}>],
#        [<AxesSubplot:title={'center':'rooms'}>,
#         <AxesSubplot:title={'center':'house_value'}>]], dtype=object)

# %%
X=data[data.columnbs[0:5]]
y=data[['house_value']]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-1b2935fbda00> in <module>
# ----> 1 X=data[data.columnbs[0:5]]
#       2 y=data[['house_value']]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'columnbs'

# %%
X=data[data.columns[0:5]]
y=data[['house_value']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.preprocesssing import MinMaxScaler
scaler= MinMaxScaler()
scaler.fit(X_train)
X_scaled_train= scaler.transform(X_train)
X_scaled_test=scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-75-870af0e3dd39> in <module>
# ----> 1 from sklearn.preprocesssing import MinMaxScaler
#       2 scaler= MinMaxScaler()
#       3 scaler.fit(X_train)
#       4 X_scaled_train= scaler.transform(X_train)
#       5 X_scaled_test=scaler.transform(X_test)
#
# ModuleNotFoundError: No module named 'sklearn.preprocesssing'

# %%
from sklearn.preprocessing import MinMaxScaler
scaler= MinMaxScaler()
scaler.fit(X_train)
X_scaled_train= scaler.transform(X_train)
X_scaled_test=scaler.transform(X_test)

# %%
from sklearn.model_selection import LinearRegression
model= LinearRegression()
model.fit(X_scaled_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-77-79e3854a7537> in <module>
# ----> 1 from sklearn.model_selection import LinearRegression
#       2 model= LinearRegression()
#       3 model.fit(X_scaled_train, y_train)
#
# ImportError: cannot import name 'LinearRegression' from 'sklearn.model_selection' (/Users/Eddie/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/__init__.py)

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(X_scaled_train, y_train)
# Out:
# LinearRegression()

# %%
pred_train=model.predict(X_scaled_train)
model.score(X_scaled_train, y_train)
# Out:
# 0.5463729131516732

# %%
pred_teest= model.predicrt(x_scaled_test)
model.score(X_scaled_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-03cdcec8cb41> in <module>
# ----> 1 pred_teest= model.predicrt(x_scaled_test)
#       2 model.score(X_scaled_test, y_test)
#
# AttributeError: 'LinearRegression' object has no attribute 'predicrt'

# %%
pred_teest= model.predict(x_scaled_test)
model.score(X_scaled_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-3cceaf284c34> in <module>
# ----> 1 pred_teest= model.predict(x_scaled_test)
#       2 model.score(X_scaled_test, y_test)
#
# NameError: name 'x_scaled_test' is not defined

# %%
pred_teest= model.predict(X_scaled_test)
model.score(X_scaled_test, y_test)
# Out:
# -2.8220648010161558

# %%
data.bedroom= data[data['bedrooms']<0.6]
data_bedroom['bedrroms'].hist(bins=100, figsize=(20,15))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-bc69d1c2071e> in <module>
#       1 data.bedroom= data[data['bedrooms']<0.6]
# ----> 2 data_bedroom['bedrroms'].hist(bins=100, figsize=(20,15))
#
# NameError: name 'data_bedroom' is not defined

# %%
data.bedroom= data[data['bedrooms']<0.6]
data_bedroom['bedrooms'].hist(bins=100, figsize=(20,15))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-12abee9ee049> in <module>
#       1 data.bedroom= data[data['bedrooms']<0.6]
# ----> 2 data_bedroom['bedrooms'].hist(bins=100, figsize=(20,15))
#
# NameError: name 'data_bedroom' is not defined

# %%
data_bedroom= data[data['bedrooms']<0.6]
data_bedroom['bedrooms'].hist(bins=100, figsize=(20,15))
# Out:
# <AxesSubplot:>

# %%
data_bedroom2 = data[data['bedrooms']>=0.6]
print(data_bedroom2['bedrooms'].value.counts())
data_bedroom2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-86-71a0ed537515> in <module>
#       1 data_bedroom2 = data[data['bedrooms']>=0.6]
# ----> 2 print(data_bedroom2['bedrooms'].value.counts())
#       3 data_bedroom2
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'value'

# %%
data_bedroom2 = data[data['bedrooms']>=0.6]
print(data_bedroom2['bedrooms'].value_counts())
data_bedroom2
# Out:
# 1.000000    3
# 0.686114    1
# 0.635258    1
# 0.750000    1
# 0.613084    1
# 0.602489    1
# 0.923077    1
# 0.625887    1
# 0.700000    1
# 0.627338    1
# 0.662539    1
# 0.658869    1
# Name: bedrooms, dtype: int64
#        housing_age  income  bedrooms  households     rooms  house_value
# 1732            43  1.3157  0.602489    2.133660  1.911826       333300
# 1911            25  1.7866  0.635258    3.566327  1.678571       325000
# 3162            26  1.4904  0.658869    3.750779  1.598131       275000
# 3165            12  1.2012  0.613084    3.271233  1.465753       275000
# 5446            24  1.8304  0.662539    3.973545  1.708995       225000
# 7674            45  1.4940  0.625887    3.673981  1.768025       187500
# 7677            20  1.0938  0.923077    1.739130  1.130435       187500
# 9658            46  2.8750  1.000000    1.846154  0.846154       162500
# 9716            16  0.5360  1.000000   18.444444  2.111111       162500
# 11810           37  2.7634  0.700000    4.524194  1.411290       137500
# 11827            4  2.3750  1.000000    3.000000  1.000000       137500
# 11863           47  1.4680  0.627338    3.458283  1.680774       137500
# 13661           25  1.3241  0.686114    3.593629  1.654440       112500
# 17908           21  0.8571  0.750000    2.370370  1.629630        25000

# %%
data_households=data[data['households']<10]
data_households['households'].hist(bins=100, figsize=(20,15))
# Out:
# <AxesSubplot:>

# %%
data_household2=data[data['households']>10]
print(data_household2['households'].value_counts())
data_households2
# Out:
# 14.000000     1
# 33.952941     1
# 12.234043     1
# 12.130081     1
# 12.843750     1
# 12.098940     1
# 18.500000     1
# 12.296089     1
# 12.895397     1
# 19.312500     1
# 16.937500     1
# 599.714286    1
# 11.634146     1
# 13.693487     1
# 18.444444     1
# 63.750000     1
# 13.594828     1
# 51.400000     1
# 10.980000     1
# 16.048780     1
# 10.153846     1
# 15.812155     1
# Name: households, dtype: int64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-89-b2221452fe31> in <module>
#       1 data_household2=data[data['households']>10]
#       2 print(data_household2['households'].value_counts())
# ----> 3 data_households2
#
# NameError: name 'data_households2' is not defined

# %%
data_household2
# Out:
#        housing_age  income  bedrooms  households      rooms  house_value
# 2420            20  1.0298  0.338658   13.693487   2.398467       300000
# 5398            33  3.8750  0.218310   12.234043   3.021277       225000
# 8003            36  4.2578  0.212528   33.952941   5.258824       183300
# 9617            26  5.7485  0.167702   51.400000   5.366667       162500
# 9625            36  4.6250  0.142857   14.000000  24.500000       162500
# 9703             8  1.6250  0.125000   63.750000   7.600000       162500
# 9713            19  0.9573  0.338843   16.048780   2.951220       162500
# 9716            16  0.5360  1.000000   18.444444   2.111111       162500
# 11397           13  3.4107  0.218182   12.843750   5.156250       142500
# 11987           41  3.5769  0.222672   18.500000   4.940000       135700
# 12290           14  2.4732  0.241758   13.594828   4.445402       131300
# 12709           41  2.2813  0.234234   12.130081   4.512195       125000
# 12794           36  2.1845  0.230769   15.812155   4.812155       123800
# 13693           22  3.5365  0.199532   12.895397   5.368201       111800
# 16828           36  5.5179  0.222222  599.714286   5.142857        67500
# 16834           26  3.5357  0.172542   10.980000   6.468000        67500
# 16839           34  3.3750  0.189189   10.153846  11.384615        67500
# 17114           22  1.9792  0.247853   12.296089   4.553073        63000
# 17610           18  1.6250  0.232708   12.098940   6.028269        53500
# 17650            8  4.0208  0.250000   19.312500   2.500000        52500
# 17799           35  1.9125  0.291667   11.634146   2.926829        47500
# 17864           16  1.6563  0.182927   16.937500   5.125000        42500

# %%
data_rooms2=data[data['rooms']>=20]
print(data_rooms2['rooms'].value_counts())
data_room2
# Out:
# 24.500000    2
# 52.690476    1
# 52.848214    1
# 29.852941    1
# 36.075472    1
#             ..
# 28.615385    1
# 20.520697    1
# 23.547368    1
# 24.024194    1
# 24.532895    1
# Name: rooms, Length: 63, dtype: int64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-91-ab9b9ccad46b> in <module>
#       1 data_rooms2=data[data['rooms']>=20]
#       2 print(data_rooms2['rooms'].value_counts())
# ----> 3 data_room2
#
# NameError: name 'data_room2' is not defined

# %%
data_rooms2
# Out:
#        housing_age  income  bedrooms  households      rooms  house_value
# 324             19  4.0714  0.177958    2.333333  61.812500       437500
# 457             17  2.1719  0.172918    2.581818  28.600000       420000
# 1140            18  5.5456  0.146182    2.273585  36.075472       360000
# 2146            17  3.9722  0.172642    2.608355  20.900783       313400
# 2858            14  4.1016  0.175109    2.136364  20.939394       283300
# ...            ...     ...       ...         ...        ...          ...
# 16222           11  3.1250  0.235332    2.484848  47.515152        77500
# 16429           16  0.4999  0.277372    1.368421  21.631579        73500
# 16584           10  3.1250  0.250564    2.285714  21.095238        71300
# 16844           25  2.6250  0.255741    1.750000  59.875000        67500
# 16848           17  2.4028  0.305361    1.740741  31.777778        67500
#
# [64 rows x 6 columns]

# %%
data_room2=data[data['rooms']>=20]
print(data_rooms2['rooms'].value_counts())
data_room2
# Out:
# 24.500000    2
# 52.690476    1
# 52.848214    1
# 29.852941    1
# 36.075472    1
#             ..
# 28.615385    1
# 20.520697    1
# 23.547368    1
# 24.024194    1
# 24.532895    1
# Name: rooms, Length: 63, dtype: int64
#        housing_age  income  bedrooms  households      rooms  house_value
# 324             19  4.0714  0.177958    2.333333  61.812500       437500
# 457             17  2.1719  0.172918    2.581818  28.600000       420000
# 1140            18  5.5456  0.146182    2.273585  36.075472       360000
# 2146            17  3.9722  0.172642    2.608355  20.900783       313400
# 2858            14  4.1016  0.175109    2.136364  20.939394       283300
# ...            ...     ...       ...         ...        ...          ...
# 16222           11  3.1250  0.235332    2.484848  47.515152        77500
# 16429           16  0.4999  0.277372    1.368421  21.631579        73500
# 16584           10  3.1250  0.250564    2.285714  21.095238        71300
# 16844           25  2.6250  0.255741    1.750000  59.875000        67500
# 16848           17  2.4028  0.305361    1.740741  31.777778        67500
#
# [64 rows x 6 columns]

# %%
new_data=data[(data['bedrooms']<0.5) & (data['households']<7) & (data['rooms']<12)]

# %%
new_data.describe()
# Out:
#         housing_age        income      bedrooms    households         rooms  \
# count  17689.000000  17689.000000  17689.000000  17689.000000  17689.000000
# mean      27.378823      3.671141      0.213278      2.952117      5.244001
# std       11.280230      1.525937      0.051167      0.731573      1.184922
# min        1.000000      0.499900      0.100000      0.750000      1.640000
# 25%       18.000000      2.532900      0.177464      2.470270      4.426829
# 50%       28.000000      3.453900      0.204104      2.854962      5.190779
# 75%       36.000000      4.591800      0.240157      3.316092      5.953728
# max       51.000000      9.905500      0.498127      6.954023     11.901869
#
#          house_value
# count   17689.000000
# mean   189043.439313
# std     95487.122628
# min     14999.000000
# 25%    114400.000000
# 50%    171100.000000
# 75%    242700.000000
# max    500000.000000

# %%
new_data.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'housing_age'}>,
#         <AxesSubplot:title={'center':'income'}>],
#        [<AxesSubplot:title={'center':'bedrooms'}>,
#         <AxesSubplot:title={'center':'households'}>],
#        [<AxesSubplot:title={'center':'rooms'}>,
#         <AxesSubplot:title={'center':'house_value'}>]], dtype=object)
