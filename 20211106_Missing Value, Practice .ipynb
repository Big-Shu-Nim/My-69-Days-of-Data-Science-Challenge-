# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data=pd.read_csv('Ex_Missing.csv')
data
# Out:
#    salary         sales        roe  industry
# 0  1095.0  27595.000000  14.100000         1
# 1     NaN   9958.000000  10.900000         1
# 2     NaN   6125.899902  23.500000         1
# 3   578.0  16246.000000   5.900000         1
# 4  1368.0           NaN  13.800000         1
# 5  1145.0           NaN  20.000000         2
# 6  1078.0   2266.699951  16.400000         2
# 7  1094.0   2966.800049  16.299999         2
# 8  1237.0   4570.200195  10.500000         2
# 9   833.0   2830.000000        NaN         2

# %%
data.nullis()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-35371e8ff610> in <module>
# ----> 1 data.nullis()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'nullis'

# %%
pd.isnull(data)
# Out:
#    salary  sales    roe  industry
# 0   False  False  False     False
# 1    True  False  False     False
# 2    True  False  False     False
# 3   False  False  False     False
# 4   False   True  False     False
# 5   False   True  False     False
# 6   False  False  False     False
# 7   False  False  False     False
# 8   False  False  False     False
# 9   False  False   True     False

# %%
pd.isnull(data).sum()
# Out:
# salary      2
# sales       2
# roe         1
# industry    0
# dtype: int64

# %%
pd.notnull(data)
# Out:
#    salary  sales    roe  industry
# 0    True   True   True      True
# 1   False   True   True      True
# 2   False   True   True      True
# 3    True   True   True      True
# 4    True  False   True      True
# 5    True  False   True      True
# 6    True   True   True      True
# 7    True   True   True      True
# 8    True   True   True      True
# 9    True   True  False      True

# %%
data['salary'].isnull().sum()
# Out:
# 2

# %%
data.notnull().sum()
# Out:
# salary       8
# sales        8
# roe          9
# industry    10
# dtype: int64

# %%
data.isnull().sum(1)
# Out:
# 0    0
# 1    1
# 2    1
# 3    0
# 4    1
# 5    1
# 6    0
# 7    0
# 8    0
# 9    1
# dtype: int64

# %%
data['missing']=data.isnull.sum(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-f40cff242f1e> in <module>
# ----> 1 data['missing']=data.isnull.sum(1)
#
# AttributeError: 'function' object has no attribute 'sum'

# %%
data['missing']=data.isnull().sum(1)

# %%
data
# Out:
#    salary         sales        roe  industry  missing
# 0  1095.0  27595.000000  14.100000         1        0
# 1     NaN   9958.000000  10.900000         1        1
# 2     NaN   6125.899902  23.500000         1        1
# 3   578.0  16246.000000   5.900000         1        0
# 4  1368.0           NaN  13.800000         1        1
# 5  1145.0           NaN  20.000000         2        1
# 6  1078.0   2266.699951  16.400000         2        0
# 7  1094.0   2966.800049  16.299999         2        0
# 8  1237.0   4570.200195  10.500000         2        0
# 9   833.0   2830.000000        NaN         2        1

# %%
del data['missing']
data['vaild']=data.notnull().sum(1)
data
# Out:
#    salary         sales        roe  industry  vaild
# 0  1095.0  27595.000000  14.100000         1      4
# 1     NaN   9958.000000  10.900000         1      3
# 2     NaN   6125.899902  23.500000         1      3
# 3   578.0  16246.000000   5.900000         1      4
# 4  1368.0           NaN  13.800000         1      3
# 5  1145.0           NaN  20.000000         2      3
# 6  1078.0   2266.699951  16.400000         2      4
# 7  1094.0   2966.800049  16.299999         2      4
# 8  1237.0   4570.200195  10.500000         2      4
# 9   833.0   2830.000000        NaN         2      3

# %%
data_del_row=data.dropna(axis=0)
data_del_row
# Out:
#    salary         sales        roe  industry  vaild
# 0  1095.0  27595.000000  14.100000         1      4
# 3   578.0  16246.000000   5.900000         1      4
# 6  1078.0   2266.699951  16.400000         2      4
# 7  1094.0   2966.800049  16.299999         2      4
# 8  1237.0   4570.200195  10.500000         2      4

# %%
data_del_col=data.dropna(axis=1)
data_del_col
# Out:
#    industry  vaild
# 0         1      4
# 1         1      3
# 2         1      3
# 3         1      4
# 4         1      3
# 5         2      3
# 6         2      4
# 7         2      4
# 8         2      4
# 9         2      3

# %%
data
# Out:
#    salary         sales        roe  industry  vaild
# 0  1095.0  27595.000000  14.100000         1      4
# 1     NaN   9958.000000  10.900000         1      3
# 2     NaN   6125.899902  23.500000         1      3
# 3   578.0  16246.000000   5.900000         1      4
# 4  1368.0           NaN  13.800000         1      3
# 5  1145.0           NaN  20.000000         2      3
# 6  1078.0   2266.699951  16.400000         2      4
# 7  1094.0   2966.800049  16.299999         2      4
# 8  1237.0   4570.200195  10.500000         2      4
# 9   833.0   2830.000000        NaN         2      3

# %%
data[['salary']].dropna()
# Out:
#    salary
# 0  1095.0
# 3   578.0
# 4  1368.0
# 5  1145.0
# 6  1078.0
# 7  1094.0
# 8  1237.0
# 9   833.0

# %%
data[['salary','roe','sales','industry']].dropna()
# Out:
#    salary        roe         sales  industry
# 0  1095.0  14.100000  27595.000000         1
# 3   578.0   5.900000  16246.000000         1
# 6  1078.0  16.400000   2266.699951         2
# 7  1094.0  16.299999   2966.800049         2
# 8  1237.0  10.500000   4570.200195         2

# %%
data[['salary','roe','sales','industry']].dropna(axis=1)
# Out:
#    industry
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# 5         2
# 6         2
# 7         2
# 8         2
# 9         2

# %%
data
# Out:
#    salary         sales        roe  industry  vaild
# 0  1095.0  27595.000000  14.100000         1      4
# 1     NaN   9958.000000  10.900000         1      3
# 2     NaN   6125.899902  23.500000         1      3
# 3   578.0  16246.000000   5.900000         1      4
# 4  1368.0           NaN  13.800000         1      3
# 5  1145.0           NaN  20.000000         2      3
# 6  1078.0   2266.699951  16.400000         2      4
# 7  1094.0   2966.800049  16.299999         2      4
# 8  1237.0   4570.200195  10.500000         2      4
# 9   833.0   2830.000000        NaN         2      3

# %%
data_0= data.fillna(0)
data_0
# Out:
#    salary         sales        roe  industry  vaild
# 0  1095.0  27595.000000  14.100000         1      4
# 1     0.0   9958.000000  10.900000         1      3
# 2     0.0   6125.899902  23.500000         1      3
# 3   578.0  16246.000000   5.900000         1      4
# 4  1368.0      0.000000  13.800000         1      3
# 5  1145.0      0.000000  20.000000         2      3
# 6  1078.0   2266.699951  16.400000         2      4
# 7  1094.0   2966.800049  16.299999         2      4
# 8  1237.0   4570.200195  10.500000         2      4
# 9   833.0   2830.000000   0.000000         2      3

# %%
data_missing= data.fillna('missing')
data_missing
# Out:
#     salary        sales        roe  industry  vaild
# 0   1095.0      27595.0       14.1         1      4
# 1  missing       9958.0       10.9         1      3
# 2  missing  6125.899902       23.5         1      3
# 3    578.0      16246.0        5.9         1      4
# 4   1368.0      missing       13.8         1      3
# 5   1145.0      missing       20.0         2      3
# 6   1078.0  2266.699951       16.4         2      4
# 7   1094.0  2966.800049  16.299999         2      4
# 8   1237.0  4570.200195       10.5         2      4
# 9    833.0       2830.0    missing         2      3

# %%
df.fillna(method='ffill' or 'pad')
data.ffill=data.fillna(method='ffill')
data_ffill
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-6a35d902ae2f> in <module>
# ----> 1 df.fillna(method='ffill' or 'pad')
#       2 data.ffill=data.fillna(method='ffill')
#       3 data_ffill
#
# NameError: name 'df' is not defined

# %%
data.ffill=data.fillna(method='ffill')
data_ffill
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-21909f6dd284> in <module>
#       1 data.ffill=data.fillna(method='ffill')
# ----> 2 data_ffill
#
# NameError: name 'data_ffill' is not defined

# %%
data_ffill=data.fillna(method='ffill')
data_ffill
# Out:
#    salary         sales        roe  industry  vaild
# 0  1095.0  27595.000000  14.100000         1      4
# 1  1095.0   9958.000000  10.900000         1      3
# 2  1095.0   6125.899902  23.500000         1      3
# 3   578.0  16246.000000   5.900000         1      4
# 4  1368.0  16246.000000  13.800000         1      3
# 5  1145.0  16246.000000  20.000000         2      3
# 6  1078.0   2266.699951  16.400000         2      4
# 7  1094.0   2966.800049  16.299999         2      4
# 8  1237.0   4570.200195  10.500000         2      4
# 9   833.0   2830.000000  10.500000         2      3

# %%
data_pad=data.fillna(method='pad')
data_pad
# Out:
#    salary         sales        roe  industry  vaild
# 0  1095.0  27595.000000  14.100000         1      4
# 1  1095.0   9958.000000  10.900000         1      3
# 2  1095.0   6125.899902  23.500000         1      3
# 3   578.0  16246.000000   5.900000         1      4
# 4  1368.0  16246.000000  13.800000         1      3
# 5  1145.0  16246.000000  20.000000         2      3
# 6  1078.0   2266.699951  16.400000         2      4
# 7  1094.0   2966.800049  16.299999         2      4
# 8  1237.0   4570.200195  10.500000         2      4
# 9   833.0   2830.000000  10.500000         2      3

# %%
data_bfill = data.fillna(method='bfill')
data_bfill
# Out:
#    salary         sales        roe  industry  vaild
# 0  1095.0  27595.000000  14.100000         1      4
# 1   578.0   9958.000000  10.900000         1      3
# 2   578.0   6125.899902  23.500000         1      3
# 3   578.0  16246.000000   5.900000         1      4
# 4  1368.0   2266.699951  13.800000         1      3
# 5  1145.0   2266.699951  20.000000         2      3
# 6  1078.0   2266.699951  16.400000         2      4
# 7  1094.0   2966.800049  16.299999         2      4
# 8  1237.0   4570.200195  10.500000         2      4
# 9   833.0   2830.000000        NaN         2      3

# %%
data_mean= data.fillna(mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-85cfe238bc6a> in <module>
# ----> 1 data_mean= data.fillna(mean())
#
# NameError: name 'mean' is not defined

# %%
data_mean= data.fillna(data.mean())

# %%
data_mean
# Out:
#    salary         sales        roe  industry  vaild
# 0  1095.0  27595.000000  14.100000         1      4
# 1  1053.5   9958.000000  10.900000         1      3
# 2  1053.5   6125.899902  23.500000         1      3
# 3   578.0  16246.000000   5.900000         1      4
# 4  1368.0   9069.825012  13.800000         1      3
# 5  1145.0   9069.825012  20.000000         2      3
# 6  1078.0   2266.699951  16.400000         2      4
# 7  1094.0   2966.800049  16.299999         2      4
# 8  1237.0   4570.200195  10.500000         2      4
# 9   833.0   2830.000000  14.600000         2      3

# %%
data_median= data.fillna(data.median())

# %%
data_max=data.fillna(data.max())
data_max
# Out:
#    salary         sales        roe  industry  vaild
# 0  1095.0  27595.000000  14.100000         1      4
# 1  1368.0   9958.000000  10.900000         1      3
# 2  1368.0   6125.899902  23.500000         1      3
# 3   578.0  16246.000000   5.900000         1      4
# 4  1368.0  27595.000000  13.800000         1      3
# 5  1145.0  27595.000000  20.000000         2      3
# 6  1078.0   2266.699951  16.400000         2      4
# 7  1094.0   2966.800049  16.299999         2      4
# 8  1237.0   4570.200195  10.500000         2      4
# 9   833.0   2830.000000  23.500000         2      3

# %%
data_min=data.fillna(data.min())
data_min
# Out:
#    salary         sales        roe  industry  vaild
# 0  1095.0  27595.000000  14.100000         1      4
# 1   578.0   9958.000000  10.900000         1      3
# 2   578.0   6125.899902  23.500000         1      3
# 3   578.0  16246.000000   5.900000         1      4
# 4  1368.0   2266.699951  13.800000         1      3
# 5  1145.0   2266.699951  20.000000         2      3
# 6  1078.0   2266.699951  16.400000         2      4
# 7  1094.0   2966.800049  16.299999         2      4
# 8  1237.0   4570.200195  10.500000         2      4
# 9   833.0   2830.000000   5.900000         2      3

# %%
data_other_mean=data.fillna(data.mean()['salary'])
data_other_mean
# Out:
#    salary         sales          roe  industry  vaild
# 0  1095.0  27595.000000    14.100000         1      4
# 1  1053.5   9958.000000    10.900000         1      3
# 2  1053.5   6125.899902    23.500000         1      3
# 3   578.0  16246.000000     5.900000         1      4
# 4  1368.0   1053.500000    13.800000         1      3
# 5  1145.0   1053.500000    20.000000         2      3
# 6  1078.0   2266.699951    16.400000         2      4
# 7  1094.0   2966.800049    16.299999         2      4
# 8  1237.0   4570.200195    10.500000         2      4
# 9   833.0   2830.000000  1053.500000         2      3

# %%
data
# Out:
#    salary         sales        roe  industry  vaild
# 0  1095.0  27595.000000  14.100000         1      4
# 1     NaN   9958.000000  10.900000         1      3
# 2     NaN   6125.899902  23.500000         1      3
# 3   578.0  16246.000000   5.900000         1      4
# 4  1368.0           NaN  13.800000         1      3
# 5  1145.0           NaN  20.000000         2      3
# 6  1078.0   2266.699951  16.400000         2      4
# 7  1094.0   2966.800049  16.299999         2      4
# 8  1237.0   4570.200195  10.500000         2      4
# 9   833.0   2830.000000        NaN         2      3

# %%
data2= data.copy()
data2['sales_new'] = np.where(pd.notnull(data2['sales']) == True,
                             data2['sales'], data2['salary'])
data2
# Out:
#    salary         sales        roe  industry  vaild     sales_new
# 0  1095.0  27595.000000  14.100000         1      4  27595.000000
# 1     NaN   9958.000000  10.900000         1      3   9958.000000
# 2     NaN   6125.899902  23.500000         1      3   6125.899902
# 3   578.0  16246.000000   5.900000         1      4  16246.000000
# 4  1368.0           NaN  13.800000         1      3   1368.000000
# 5  1145.0           NaN  20.000000         2      3   1145.000000
# 6  1078.0   2266.699951  16.400000         2      4   2266.699951
# 7  1094.0   2966.800049  16.299999         2      4   2966.800049
# 8  1237.0   4570.200195  10.500000         2      4   4570.200195
# 9   833.0   2830.000000        NaN         2      3   2830.000000

# %%
data.groupby('industry').mean()
# Out:
#                salary         sales    roe  vaild
# industry
# 1         1013.666667  14981.224975  13.64    3.4
# 2         1077.400000   3158.425049  15.80    3.6

# %%
fill_mean_func = lambda g: g.fillna(g.mean())

data_group_mean=data.groupby('industry').apply(fill_mean_func)
data_group.mean
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-b492f2ba9cd1> in <module>
#       2
#       3 data_group_mean=data.groupby('industry').apply(fill_mean_func)
# ----> 4 data_group.mean
#
# NameError: name 'data_group' is not defined

# %%
fill_mean_func = lambda g: g.fillna(g.mean())

data_group_mean=data.groupby('industry').apply(fill_mean_func)
data_group_mean
# Out:
#                  salary         sales        roe  industry  vaild
# industry
# 1        0  1095.000000  27595.000000  14.100000         1      4
#          1  1013.666667   9958.000000  10.900000         1      3
#          2  1013.666667   6125.899902  23.500000         1      3
#          3   578.000000  16246.000000   5.900000         1      4
#          4  1368.000000  14981.224975  13.800000         1      3
# 2        5  1145.000000   3158.425049  20.000000         2      3
#          6  1078.000000   2266.699951  16.400000         2      4
#          7  1094.000000   2966.800049  16.299999         2      4
#          8  1237.000000   4570.200195  10.500000         2      4
#          9   833.000000   2830.000000  15.800000         2      3

# %%
fill_values = {1: 1000, 2: 2000}
fill_func = lambda d: d.fillna(fill_values[d.name])

# %%
data_group_value= data.groupby('industry').apply(fill.func)
data_group_value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-451c08af6fac> in <module>
# ----> 1 data_group_value= data.groupby('industry').apply(fill.func)
#       2 data_group_value
#
# NameError: name 'fill' is not defined

# %%
data_group_value= data.groupby('industry').apply(fill_func)
data_group_value
# Out:
#    salary         sales          roe  industry  vaild
# 0  1095.0  27595.000000    14.100000         1      4
# 1  1000.0   9958.000000    10.900000         1      3
# 2  1000.0   6125.899902    23.500000         1      3
# 3   578.0  16246.000000     5.900000         1      4
# 4  1368.0   1000.000000    13.800000         1      3
# 5  1145.0   2000.000000    20.000000         2      3
# 6  1078.0   2266.699951    16.400000         2      4
# 7  1094.0   2966.800049    16.299999         2      4
# 8  1237.0   4570.200195    10.500000         2      4
# 9   833.0   2830.000000  2000.000000         2      3

# %%
missing_fill_val= {'salary': data.salary.interpolate(),
                  'sales': data.sales.mean(),
                  'roe': 'missing'}
print(missing_fill_val)
# Out:
# {'salary': 0    1095.000000
# 1     922.666667
# 2     750.333333
# 3     578.000000
# 4    1368.000000
# 5    1145.000000
# 6    1078.000000
# 7    1094.000000
# 8    1237.000000
# 9     833.000000
# Name: salary, dtype: float64, 'sales': 9069.825012125, 'roe': 'missing'}

# %%
data_multi= data.fillna(missing_fill_val)
data_multi
# Out:
#         salary         sales        roe  industry  vaild
# 0  1095.000000  27595.000000       14.1         1      4
# 1   922.666667   9958.000000       10.9         1      3
# 2   750.333333   6125.899902       23.5         1      3
# 3   578.000000  16246.000000        5.9         1      4
# 4  1368.000000   9069.825012       13.8         1      3
# 5  1145.000000   9069.825012       20.0         2      3
# 6  1078.000000   2266.699951       16.4         2      4
# 7  1094.000000   2966.800049  16.299999         2      4
# 8  1237.000000   4570.200195       10.5         2      4
# 9   833.000000   2830.000000    missing         2      3

# %%
data2=pd.read_csv('house_raw.csv')
data.head()
# Out:
#    salary         sales   roe  industry  vaild
# 0  1095.0  27595.000000  14.1         1      4
# 1     NaN   9958.000000  10.9         1      3
# 2     NaN   6125.899902  23.5         1      3
# 3   578.0  16246.000000   5.9         1      4
# 4  1368.0           NaN  13.8         1      3

# %%
data2.head()
# Out:
#    housing_age  income  bedrooms  households     rooms  house_value
# 0           23  6.7770  0.141112    2.442244  8.103960       500000
# 1           49  6.0199  0.160984    2.726688  5.752412       500000
# 2           35  5.1155  0.249061    1.902676  3.888078       500000
# 3           32  4.7109  0.231383    1.913669  4.508393       500000
# 4           21  4.5625  0.255583    3.092664  4.667954       500000

# %%
data2.describe()
# Out:
#         housing_age        income      bedrooms    households         rooms  \
# count  17914.000000  17914.000000  17914.000000  17914.000000  17914.000000
# mean      27.307022      3.664086      0.214309      3.007667      5.370672
# std       11.297204      1.526694      0.055251      4.579534      2.332776
# min        1.000000      0.499900      0.100000      0.692308      0.846154
# 25%       18.000000      2.526125      0.177544      2.467031      4.426115
# 50%       28.000000      3.447800      0.204256      2.853499      5.199222
# 75%       36.000000      4.583300      0.240476      3.318866      5.970848
# max       51.000000      9.905500      1.000000    599.714286    132.533333
#
#          house_value
# count   17914.000000
# mean   188692.620130
# std     95318.621139
# min     14999.000000
# 25%    114325.000000
# 50%    170800.000000
# 75%    242100.000000
# max    500000.000000

# %%
data2.hist(bins=50, figsize=(10,15))
# Out:
# array([[<AxesSubplot:title={'center':'housing_age'}>,
#         <AxesSubplot:title={'center':'income'}>],
#        [<AxesSubplot:title={'center':'bedrooms'}>,
#         <AxesSubplot:title={'center':'households'}>],
#        [<AxesSubplot:title={'center':'rooms'}>,
#         <AxesSubplot:title={'center':'house_value'}>]], dtype=object)

# %%
X=data[data.columns[0:5]]
y=data[['house_value']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-cef0be36b8fb> in <module>
#       1 X=data[data.columns[0:5]]
# ----> 2 y=data[['house_value']]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ...

# %%
X=data2[data2.columns[0:5]]
y=data2[['house_value']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit(X_train)
X_scaled_train=scaler.transform(X_train)
X_scaled_test=scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_scaled_train, y_train)
# Out:
# LinearRegression()

# %%
pred_train=model.predict(X_scaled_train)
model.score(X_scaled_train, y_train)
# Out:
# 0.5463729131516732

# %%
pred_test= model.predict(X_scaled_test)
model. score(X_scaled_test, y_test)
# Out:
# -2.8220648010161558

# %%
data_bedroom=data[data['bedrroms']<0.6]
data_bedroom['bedrroom'].hist(bins=100, figsize(10,15))
# Out:
#   File "<ipython-input-55-f626422e5270>", line 2
#     data_bedroom['bedrroom'].hist(bins=100, figsize(10,15))
#                                             ^
# SyntaxError: positional argument follows keyword argument

# %%
data_bedroom=data[data['bedrroms']<0.6]
data_bedroom['bedrroom'].hist(bins=100, figsize=(15,10))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'bedrroms'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-e0a1f9fe96bc> in <module>
# ...

# %%
data_bedroom=data[data['bedrooms']<0.6]
data_bedroom['bedrooms'].hist(bins=100, figsize=(15,10))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'bedrooms'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-5cc03eb24a9a> in <module>
# ...

# %%
data_bedroom=data2[data2['bedrooms']<0.6]
data_bedroom['bedrooms'].hist(bins=100, figsize=(15,10))
# Out:
# <AxesSubplot:>

# %%
data_bedroom2=data2[data2['bedrooms']>=0.6]
print(data_bedroom2['bedrooms'].value_counts())
data_bedroom2
# Out:
# 1.000000    3
# 0.686114    1
# 0.635258    1
# 0.750000    1
# 0.613084    1
# 0.602489    1
# 0.923077    1
# 0.625887    1
# 0.700000    1
# 0.627338    1
# 0.662539    1
# 0.658869    1
# Name: bedrooms, dtype: int64
#        housing_age  income  bedrooms  households     rooms  house_value
# 1732            43  1.3157  0.602489    2.133660  1.911826       333300
# 1911            25  1.7866  0.635258    3.566327  1.678571       325000
# 3162            26  1.4904  0.658869    3.750779  1.598131       275000
# 3165            12  1.2012  0.613084    3.271233  1.465753       275000
# 5446            24  1.8304  0.662539    3.973545  1.708995       225000
# 7674            45  1.4940  0.625887    3.673981  1.768025       187500
# 7677            20  1.0938  0.923077    1.739130  1.130435       187500
# 9658            46  2.8750  1.000000    1.846154  0.846154       162500
# 9716            16  0.5360  1.000000   18.444444  2.111111       162500
# ...

# %%
data_households=data[data['households']<10]
data_households['households'].hist(bins=100, figsize=(20,15))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'households'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-99cfd27d9fbd> in <module>
# ...

# %%
data_households=data2[data2['households']<10]
data_households['households'].hist(bins=100, figsize=(20,15))
# Out:
# <AxesSubplot:>

# %%
data_households2=data2[data2['households']>=10]
print(data_households2['hoseholds'].value_counts())
data_households2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'hoseholds'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-642acb3c0627> in <module>
# ...

# %%
data_households=data[data['households']<10]
data_households['households'].hist(bins=100, figsize=(20,15))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'households'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-8467b80ad87b> in <module>
# ...

# %%
data_households=data2[data2['households']<10]
data_households['households'].hist(bins=100, figsize=(20,15))
# Out:
# <AxesSubplot:>

# %%
data_households2=data2[data2['households']>=10]
print(data_households2['households'].value_counts())
data_households2
# Out:
# 14.000000     1
# 33.952941     1
# 12.234043     1
# 12.130081     1
# 12.843750     1
# 12.098940     1
# 18.500000     1
# 12.296089     1
# 12.895397     1
# 19.312500     1
# 16.937500     1
# 599.714286    1
# 11.634146     1
# 13.693487     1
# 18.444444     1
# 63.750000     1
# 13.594828     1
# 51.400000     1
# 10.980000     1
# 16.048780     1
# 10.153846     1
# 15.812155     1
# Name: households, dtype: int64
#        housing_age  income  bedrooms  households      rooms  house_value
# 2420            20  1.0298  0.338658   13.693487   2.398467       300000
# 5398            33  3.8750  0.218310   12.234043   3.021277       225000
# 8003            36  4.2578  0.212528   33.952941   5.258824       183300
# 9617            26  5.7485  0.167702   51.400000   5.366667       162500
# 9625            36  4.6250  0.142857   14.000000  24.500000       162500
# 9703             8  1.6250  0.125000   63.750000   7.600000       162500
# ...

# %%
data_room = data2[data2['rooms']<20]
data_room['rooms'].hist(bins=100, figsize=(20,15))
# Out:
# <AxesSubplot:>

# %%
data_room2=data2[data2['rooms']>=20]
print(data_room2['rooms'].value_counts())
data_room2
# Out:
# 24.500000    2
# 52.690476    1
# 52.848214    1
# 29.852941    1
# 36.075472    1
#             ..
# 28.615385    1
# 20.520697    1
# 23.547368    1
# 24.024194    1
# 24.532895    1
# Name: rooms, Length: 63, dtype: int64
#        housing_age  income  bedrooms  households      rooms  house_value
# 324             19  4.0714  0.177958    2.333333  61.812500       437500
# 457             17  2.1719  0.172918    2.581818  28.600000       420000
# 1140            18  5.5456  0.146182    2.273585  36.075472       360000
# 2146            17  3.9722  0.172642    2.608355  20.900783       313400
# 2858            14  4.1016  0.175109    2.136364  20.939394       283300
# ...            ...     ...       ...         ...        ...          ...
# 16222           11  3.1250  0.235332    2.484848  47.515152        77500
# 16429           16  0.4999  0.277372    1.368421  21.631579        73500
# 16584           10  3.1250  0.250564    2.285714  21.095238        71300
# ...

# %%
new_data=data2[(data2['bedroom']<0.5) &(data2['households']<7) & (data2['rooms']<12)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'bedroom'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-36466bc1a056> in <module>
# ...

# %%
new_data=data2[(data2['bedrooms']<0.5) &(data2['households']<7) & (data2['rooms']<12)]

# %%
new_data.describe()
# Out:
#         housing_age        income      bedrooms    households         rooms  \
# count  17689.000000  17689.000000  17689.000000  17689.000000  17689.000000
# mean      27.378823      3.671141      0.213278      2.952117      5.244001
# std       11.280230      1.525937      0.051167      0.731573      1.184922
# min        1.000000      0.499900      0.100000      0.750000      1.640000
# 25%       18.000000      2.532900      0.177464      2.470270      4.426829
# 50%       28.000000      3.453900      0.204104      2.854962      5.190779
# 75%       36.000000      4.591800      0.240157      3.316092      5.953728
# max       51.000000      9.905500      0.498127      6.954023     11.901869
#
#          house_value
# count   17689.000000
# mean   189043.439313
# std     95487.122628
# min     14999.000000
# 25%    114400.000000
# 50%    171100.000000
# 75%    242700.000000
# max    500000.000000

# %%
new_data.hist(bins=50, figsize=(15,10))
# Out:
# array([[<AxesSubplot:title={'center':'housing_age'}>,
#         <AxesSubplot:title={'center':'income'}>],
#        [<AxesSubplot:title={'center':'bedrooms'}>,
#         <AxesSubplot:title={'center':'households'}>],
#        [<AxesSubplot:title={'center':'rooms'}>,
#         <AxesSubplot:title={'center':'house_value'}>]], dtype=object)

# %%
X=new_data[new_data.columns[0:5]]
y=new_data[['house_value']]

from sklearn.model_selection train_test_split
X_train, X_test, y_train, y_test=train_test_split(X_,y, random_state=42)
# Out:
#   File "<ipython-input-72-69b84fbd3db7>", line 4
#     from sklearn.model_selection train_test_split
#                                  ^
# SyntaxError: invalid syntax

# %%
X=new_data[new_data.columns[0:5]]
y=new_data[['house_value']]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X_,y, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-f355709c079c> in <module>
#       3
#       4 from sklearn.model_selection import train_test_split
# ----> 5 X_train, X_test, y_train, y_test=train_test_split(X_,y, random_state=42)
#
# NameError: name 'X_' is not defined

# %%
X=new_data[new_data.columns[0:5]]
y=new_data[['house_value']]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit(X_train)
X_scaled_train= scaler.transform(X_train)
X_scaled_test=scaler.transform(X_test)

# %%
from sklearn.linear import LinearRegression
model=LinearRegression()
model.fit(X_scaled_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-76-73d85e1312ce> in <module>
# ----> 1 from sklearn.linear import LinearRegression
#       2 model=LinearRegression()
#       3 model.fit(X_scaled_train, y_train)
#
# ModuleNotFoundError: No module named 'sklearn.linear'

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_scaled_train, y_train)
# Out:
# LinearRegression()

# %%
pred_train=mdoel.predict(X_scaled_train)
model.score(X_scaled_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-e4a9e5b37709> in <module>
# ----> 1 pred_train=mdoel.predict(X_scaled_train)
#       2 model.score(X_scaled_train, y_train)
#
# NameError: name 'mdoel' is not defined

# %%
pred_train=model.predict(X_scaled_train)
model.score(X_scaled_train, y_train)
# Out:
# 0.5706921210926263

# %%
pred_test=model.predict(X_scaled_test)
model.score(X_scaled_test, y_test)
# Out:
# 0.5826083517811866

# %%
new_data.to_csv('house_price.csv', index=false)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-730a137f3f78> in <module>
# ----> 1 new_data.to_csv('house_price.csv', index=false)
#
# NameError: name 'false' is not defined

# %%
new_data.to_csv('house_price.csv', index=False)
